# %%
import matplotlib.pyplot as plt
import pandas as pd

from scipy.signal import savgol_filter

# %%
df_dqn = pd.read_csv('dqn_distaceReal.csv',index_col = 1)
df_rainbow = pd.read_csv('RAINBOW_NormalDQN_Dista.csv',index_col = 1)

# %%
sec = df_dqn.loc[299486]['Wall time'] - df_dqn.loc[168]['Wall time']
print(sec)
# Out:
# 8821.509649276733

# %%
df_rainbow.loc[299486]['Wall time'] - df_rainbow.loc[168]['Wall time']
# Out:
# 12818.098831892014

# %%
12818.098831892014/8821.509649276733 * 100
# Out:
# 145.3050480191104

# %% [markdown]
# #### Rolling

# %%
dfdqnrol = df_dqn.copy()
dfdqnrol.Value = df_dqn.Value.rolling(100).mean()

# %%
df_rainbow_roll = df_rainbow.copy()
df_rainbow_roll.Value = df_rainbow.Value.rolling(100).mean()

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = go.Figure()
df_dqn = pd.read_csv('dqn_distaceReal.csv')
df_rainbow = pd.read_csv('RAINBOW_NormalDQN_Dista.csv')
fig.add_trace(go.Scatter(x=df_dqn.Step, y=df_dqn.Value,
                    mode='lines',
                    name='DQN'))
fig.add_trace(go.Scatter(x=df_rainbow.Step, y=df_rainbow.Value,
                    mode='lines',
                    name='Rainbow'))
fig.show()

df_dqn = pd.read_csv('dqn_distaceReal.csv',index_col = 1)
df_rainbow = pd.read_csv('RAINBOW_NormalDQN_Dista.csv',index_col = 1)

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=dfdqnrol.Step, y=dfdqnrol.Value,
                    mode='lines',
                    name='DQN'))
fig.add_trace(go.Scatter(x=df_rainbow_roll.Step, y=df_rainbow_roll.Value,
                    mode='lines',
                    name='Rainbow'))
fig.show()

# %% [markdown]
# ## smooth

# %%
df_dqn = pd.read_csv('dqn_distaceReal.csv',index_col=1)
df_rainbow = pd.read_csv('RAINBOW_NormalDQN_Dista.csv',index_col=1)

# %%
dfdqnsvkol = df_dqn.copy()
dfdqnsvkol.Value = savgol_filter(df_dqn.Value,50,1)
df_rainbow_svkol = df_rainbow.copy()
df_rainbow_svkol.Value = savgol_filter(df_rainbow.Value,50,1)

# %%
plt.figure(figsize=(16,6))
plt.plot(dfdqnsvkol.Value,label='DQN')
plt.plot(df_rainbow_svkol.Value,label='RAINBOW')
plt.legend()
plt.show()

# %%
# plt.figure(figsize=(16,6))
# plt.plot(dfdqnrol.Value,label='DQN')
# plt.plot(df_rainbow_roll.Value,label='RAINBOW')
# plt.legend()
# plt.show()

# %% [markdown]
# # plot

# %%
df_dqn = pd.read_csv('dqn_distaceReal.csv',index_col=1)
df_rainbow = pd.read_csv('RAINBOW_NormalDQN_Dista.csv',index_col=1)

# %%
dfdqnrol = df_dqn.copy()
dfdqnrol.Value = df_dqn.Value.rolling(100).mean()

df_rainbow_roll = df_rainbow.copy()
df_rainbow_roll.Value = df_rainbow.Value.rolling(100).mean()

# %% [markdown]
# rolling method

# %%
plt.figure(figsize=(16,6))
plt.plot(dfdqnrol.Value,label='DQN')
plt.plot(df_rainbow_roll.Value,label='RAINBOW')
plt.legend()
plt.show()

# %% [markdown]
# signal smoothing method

# %%
dfdqnsvkol = df_dqn.copy()
dfdqnsvkol.Value = savgol_filter(df_dqn.Value,100,1)
df_rainbow_svkol = df_rainbow.copy()
df_rainbow_svkol.Value = savgol_filter(df_rainbow.Value,100,1)

# %%
plt.figure(figsize=(16,6))
plt.plot(dfdqnsvkol.Value[50:950],label='DQN')
plt.plot(df_rainbow_svkol.Value[50:950],label='RAINBOW')
plt.legend()
plt.show()

# %%
df_rainbow = pd.read_csv('RAINBOW_NormalDQN_Dista.csv',index_col=1)
df_rainbowtf = pd.read_csv('RAINBOW_tf_Dista.csv',index_col=1)
df_rainbowlstm = pd.read_csv('RAINBOW_lstm_Dista.csv',index_col=1)


df_rainbow_roll = df_rainbow.copy()
df_rainbow_roll.Value = df_rainbow.Value.rolling(200).mean()

df_rainbowtf_roll = df_rainbowtf.copy()
df_rainbowtf_roll.Value = df_rainbowtf.Value.rolling(200).mean()

df_rainbowlstm_roll = df_rainbowlstm.copy()
df_rainbowlstm_roll.Value = df_rainbowlstm.Value.rolling(200).mean()

# %% [markdown]
# rolling

# %%
plt.figure(figsize=(16,6))

plt.plot(df_rainbow_roll[50:950].Value,label='Traditional Rainbow')
plt.plot(df_rainbowtf_roll[50:950].Value,label='Rainbow with Transformer')
plt.plot(df_rainbowlstm_roll[50:950].Value,label='Rainbow with LSTM')
plt.legend()
plt.show()

# %%
df_rainbowNorm = pd.read_csv('RAINBOW_NormalDQN_Dista.csv',index_col=1)
df_rainbow000 =  pd.read_csv('0.00025_1M_dist.csv',index_col=1)

df_rainbowNorm_svk = df_rainbowNorm.copy()
df_rainbowNorm_svk.Value = savgol_filter(df_rainbowNorm.Value,100,1)

df_rainbow000_svk = df_rainbow000.copy()
df_rainbow000_svk.Value = savgol_filter(df_rainbow000.Value,100,1)


plt.figure(figsize=(10,6))
plt.plot(df_rainbow000_svk.Value[0:611],label='LR = 2.5e-04')
plt.plot(df_rainbowNorm_svk.Value[0:764],label='LR = 6.25e-05')
# plt.plot(df_rainbowtf_svk.Value[0:978],label='Rainbow with Transformer')
# plt.plot(df_rainbowlstm_svk.Value[0:774],label='Rainbow with LSTM')
plt.xlim([-20000, 620000])
plt.legend()
plt.show()

# %%
df_rainbow000 =  pd.read_csv('0.00025_1M_dist.csv',index_col=1)
df_rainbow000per =  pd.read_csv('Rainbow_0.00025_w_permanent_dist.csv',index_col=1)

df_rainbow000_svk = df_rainbow000.copy()
df_rainbow000_svk.Value = savgol_filter(df_rainbow000.Value,200,1)

df_rainbow000per_svk = df_rainbow000per.copy()
df_rainbow000per_svk.Value = savgol_filter(df_rainbow000per.Value,200,1)

plt.figure(figsize=(10,6))
plt.plot(df_rainbow000_svk.Value[0:674],label='without permanent memory')
plt.plot(df_rainbow000per_svk.Value[:930],label='with permanent memory')
plt.xlim([-20000, 700000])
plt.legend()
plt.show()

# %%
# !wget https://github.com/AtiChetsurakul/BrosOfRainbow/raw/main/ranbow_New_variant/2_action_permanent_mem_dist.csv
# Out:
# --2023-05-08 09:44:25--  https://github.com/AtiChetsurakul/BrosOfRainbow/raw/main/ranbow_New_variant/2_action_permanent_mem_dist.csv
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/AtiChetsurakul/BrosOfRainbow/main/ranbow_New_variant/2_action_permanent_mem_dist.csv [following]
# --2023-05-08 09:44:25--  https://raw.githubusercontent.com/AtiChetsurakul/BrosOfRainbow/main/ranbow_New_variant/2_action_permanent_mem_dist.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32570 (32K) [text/plain]
# Saving to: ‘2_action_permanent_mem_dist.csv’
#
# ...

# %%
df_rainbow40Per =  pd.read_csv('2_action_permanent_mem_dist.csv',index_col=1)
df_dqn = pd.read_csv('dqn_distaceReal.csv',index_col=1)

df_rainbow40Per_svk = df_rainbow40Per.copy()
df_rainbow40Per_svk.Value = savgol_filter(df_rainbow40Per.Value,100,1)
dfdqnsvkol = df_dqn.copy()
dfdqnsvkol.Value = savgol_filter(df_dqn.Value,100,1)

plt.plot(dfdqnsvkol.Value,label='ddqn')
plt.plot(df_rainbow40Per_svk.Value,label='ddqn')

# %%
0.00025/4
# Out:
# 6.25e-05

# %% [markdown]
# signal smoothing

# %%
df_rainbow = pd.read_csv('RAINBOW_NormalDQN_Dista.csv',index_col=1)
df_rainbowtf = pd.read_csv('RAINBOW_tf_Dista.csv',index_col=1)
df_rainbowlstm = pd.read_csv('RAINBOW_lstm_Dista.csv',index_col=1)


df_rainbow_svk = df_rainbow.copy()
df_rainbow_svk.Value = savgol_filter(df_rainbow.Value,100,1)

df_rainbowtf_svk = df_rainbowtf.copy()
df_rainbowtf_svk.Value = savgol_filter(df_rainbowtf.Value,100,1)

df_rainbowlstm_svk = df_rainbowlstm.copy()
df_rainbowlstm_svk.Value = savgol_filter(df_rainbowlstm.Value,100,1)

plt.figure(figsize=(8,5))
plt.plot(dfdqnsvkol.Value[0:611],label='DDQN')
plt.plot(df_rainbow_svk.Value[0:764],label='Traditional Rainbow')
plt.plot(df_rainbowtf_svk.Value[0:978],label='Rainbow with Transformer')
plt.plot(df_rainbowlstm_svk.Value[0:774],label='Rainbow with LSTM')
plt.plot(df_rainbow40Per_svk.Value,label='Rainbow with 40K P-mem')
plt.xlim([-20000, 620000])
plt.legend()
plt.show()

# %%
# sec1 = df_dqn.loc[299486]['Wall time'] - df_dqn.loc[168]['Wall time']
sec2 = df_rainbowtf.loc[299486]['Wall time'] - df_rainbowtf.loc[168]['Wall time']
sec3 = df_rainbowlstm.loc[299486]['Wall time'] - df_rainbowlstm.loc[168]['Wall time']
print(sec2/8821.509649276733 * 100)
print(sec3/8821.509649276733 * 100)
# Out:
# 332.61548250475965
# 180.8277022030144

# %%
loss_rainbow = pd.read_csv('RAINBOW_NormalDQN_loss.csv',index_col=1)
loss_rainbowtf = pd.read_csv('RAINBOW_tf_loss.csv',index_col=1)
loss_rainbowlstm = pd.read_csv('RAINBOW_lstm_loss.csv',index_col=1)


loss_rainbow_roll = loss_rainbow.copy()
# loss_rainbow_roll.Value = savgol_filter(loss_rainbow.Value,200,1)

loss_rainbowtf_roll = loss_rainbowtf.copy()
# loss_rainbowtf_roll.Value = savgol_filter(loss_rainbowtf.Value,200,1)

loss_rainbowlstm_roll = loss_rainbowlstm.copy()
# loss_rainbowlstm_roll.Value = savgol_filter(loss_rainbowlstm.Value,200,1)


plt.figure(figsize=(16,6))
plt.plot(loss_rainbow_roll.Value,label='Traditional Rainbow')
plt.plot(loss_rainbowtf_roll.Value,label='Rainbow with Transformer')
plt.plot(loss_rainbowlstm_roll.Value,label='Rainbow with LSTM')
plt.legend()
plt.show()

# %%
loss_rainbow.head()
# Out:
#          Wall time     Value
# Step
# 201   1.682736e+09  1.095546
# 508   1.682736e+09  0.959709
# 570   1.682736e+09  0.920316
# 620   1.682736e+09  0.867151
# 1470  1.682736e+09  0.495336

# %%
loss_rainbow_roll.head()
# Out:
#          Wall time     Value
# Step
# 201   1.682736e+09  1.095546
# 508   1.682736e+09  0.959709
# 570   1.682736e+09  0.920316
# 620   1.682736e+09  0.867151
# 1470  1.682736e+09  0.495336

# %% [markdown]
# \begin{equation}
# L(\theta) = \mathbb{E}{s,a,r,s'} \left[ \left( r + \gamma \max{a'} Q_{\theta^-}(s',a') - Q_{\theta}(s,a) \right)^2 \right]
#
# \lambda \sum_{i=1}^{N} w_i \left( \mathbb{E}_{s,a,r,s'} \left[ \left( \mathcal{D}i(s,a) - Q{\theta}(s,a) \right)^2 \right] - \sigma^2_i \right)^2
# \end{equation}

# %%
df_rainbow = pd.read_csv('RAINBOW_NormalDQN_Dista.csv',index_col=1)
df_rainbow_simple = pd.read_csv('Simple_movement_1M_Dist.csv',index_col=1)

# %%
plt.figure(figsize=(16,6))
plt.plot(df_rainbow.Value[50:950],label='DQN')
plt.plot(df_rainbow_simple.Value[50:950],label='RAINBOW')
plt.legend()
plt.show()

# %%
df_rainbow_svk = df_rainbow.copy()
df_rainbow_svk.Value = savgol_filter(df_rainbow.Value,100,1)

df_rainbow_simple = df_rainbow_simple.copy()
df_rainbow_simple.Value = savgol_filter(df_rainbow_simple.Value,100,1)

# %%
plt.figure(figsize=(10,6))
#plt.plot(df_rainbow_svk.Value[50:730],label='Traditional Rainbow with 2 actions')
plt.plot(df_rainbow_svk.Value[0:764],label='Traditional Rainbow with 2 actions')
plt.plot(df_rainbow_simple.Value[0:612],label='Traditional Rainbow with 5 actions')
plt.xlim([-20000, 620000])
plt.legend(loc='upper left')
plt.show()

# %%
df_rainbow_svk
# Out:
#            Wall time       Value
# Step
# 168     1.682736e+09  437.984158
# 475     1.682736e+09  438.682862
# 537     1.682736e+09  439.381566
# 587     1.682736e+09  440.080270
# 1437    1.682736e+09  440.778974
# ...              ...         ...
# 780484  1.682786e+09  392.993633
# 780591  1.682786e+09  392.624482
# 780859  1.682786e+09  392.255332
# 781686  1.682786e+09  391.886181
# 785554  1.682805e+09  391.517030
#
# [1000 rows x 2 columns]
